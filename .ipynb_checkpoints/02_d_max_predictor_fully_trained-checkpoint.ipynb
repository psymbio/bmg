# %%
import os
import sklearn
import seaborn as sns
import numpy as np
import pandas as pd
import re
import pickle
from tqdm import tqdm
import datetime
import time

from PyAstronomy import pyasl

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from imblearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer, MissingIndicator

from sklearn.preprocessing import (
    StandardScaler, 
    MinMaxScaler, 
    MaxAbsScaler, 
    # RobustScalar,
    Normalizer,
    QuantileTransformer,
    PowerTransformer,
    OneHotEncoder, 
    OrdinalEncoder,
    LabelEncoder
)

from sklearn.utils import all_estimators

from sklearn.base import (
    RegressorMixin, 
    ClassifierMixin,
    TransformerMixin
)

from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    auc,
    roc_auc_score,
    f1_score,
    r2_score,
    mean_squared_error,
    classification_report
)

import warnings
import xgboost
import catboost
import lightgbm

import tensorflow as tf

warnings.filterwarnings("ignore")
pd.set_option("display.precision", 2)
pd.set_option("display.float_format", lambda x: "%.2f" % x)

removed_classifiers = [
    "ClassifierChain",
    "ComplementNB",
    # "GradientBoostingClassifier",
    "GaussianProcessClassifier",
    "HistGradientBoostingClassifier",
    # "MLPClassifier",
    "LogisticRegressionCV", 
    "MultiOutputClassifier", 
    "MultinomialNB", 
    "OneVsOneClassifier",
    "OneVsRestClassifier",
    "OutputCodeClassifier",
    "RadiusNeighborsClassifier",
    "VotingClassifier",
    "CategoricalNB",
    "StackingClassifier",
    "NuSVC",
]

removed_regressors = [
    "TheilSenRegressor",
    "ARDRegression", 
    "CCA", 
    "IsotonicRegression", 
    "StackingRegressor",
    "MultiOutputRegressor", 
    "MultiTaskElasticNet", 
    "MultiTaskElasticNetCV", 
    "MultiTaskLasso", 
    "MultiTaskLassoCV", 
    "PLSCanonical", 
    "PLSRegression", 
    "RadiusNeighborsRegressor", 
    "RegressorChain", 
    "VotingRegressor", 
]

CLASSIFIERS = [
    est
    for est in all_estimators()
    if (issubclass(est[1], ClassifierMixin) and (est[0] not in removed_classifiers))
]


REGRESSORS = [
    est
    for est in all_estimators()
    if (issubclass(est[1], RegressorMixin) and (est[0] not in removed_regressors))
]

REGRESSORS.append(("XGBRegressor", xgboost.XGBRegressor))
REGRESSORS.append(("LGBMRegressor", lightgbm.LGBMRegressor))
REGRESSORS.append(('CatBoostRegressor', catboost.CatBoostRegressor))

CLASSIFIERS.append(("XGBClassifier", xgboost.XGBClassifier))
CLASSIFIERS.append(("LGBMClassifier", lightgbm.LGBMClassifier))
CLASSIFIERS.append(('CatBoostClassifier', catboost.CatBoostClassifier))

TRANSFOMER_METHODS = [
    ("StandardScaler", StandardScaler), 
    ("MinMaxScaler", MinMaxScaler), 
    ("MaxAbsScaler", MaxAbsScaler), 
    # ("RobustScalar", RobustScalar),
    ("Normalizer", Normalizer),
    ("QuantileTransformer", QuantileTransformer),
    ("PowerTransformer", PowerTransformer),
]

def adjusted_rsquared(r2, n, p):
    return 1 - (1 - r2) * ((n - 1) / (n - p - 1))
# Out:
# 2023-05-19 06:33:10.789731: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-19 06:33:11.784071: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-05-19 06:33:13.857275: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-05-19 06:33:13.857729: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-05-19 06:33:13.857754: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# References:
#
# 1. https://discuss.huggingface.co/t/what-does-increasing-number-of-heads-do-in-the-multi-head-attention/1847/2

# %%
df_train = pd.read_excel("dataset.xlsx", sheet_name="train")
df_test = pd.read_excel("dataset.xlsx", sheet_name="test")
display(df_train)
display(df_test)
# Out:
#                           bmg_alloy  delta_h_mix  delta_s_mix  delta_d  \
# 0                        Al92Nd6Ni2        10.61         0.32     0.20
# 1          Zr26Ti10Cu8Ni8Be20Y4Mg24        13.89         1.78     0.17
# 2                   Gd55Ni22Mn3Al20        11.82         1.09     0.26
# 3                Ag53.8Mg15.4Ca30.8        10.05         0.98     0.25
# 4                      Ni60Nb20Zr20        19.88         0.95     0.17
# ...                             ...          ...          ...      ...
# 1054  Mg65Cu7.5Ni7.5Ag5Zn5Gd7.5Y2.5         9.89         1.25     0.18
# 1055  Mg65Cu7.5Ni7.5Ag5Zn5Gd2.5Y7.5         9.96         1.25     0.17
# 1056                   Mg80Ni10Nd10         9.39         0.64     0.25
# 1057             Cu45.5Mg31.8Ca22.7        10.66         1.06     0.34
# 1058          Mg59.5Cu22.9Ag6.6Gd11        10.02         1.07     0.20
#
#       delta_e  actual_d_max
# 0       -0.17          0.00
# 1       -0.12          5.00
# 2       -0.18          2.00
# 3       -0.28          0.80
# 4       -0.13          0.50
# ...       ...           ...
# 1054    -0.16         13.00
# 1055    -0.16          9.50
# 1056    -0.09          0.60
# 1057    -0.25          1.25
# 1058    -0.19         27.00
#
# [1059 rows x 6 columns]
#                    bmg_alloy  delta_h_mix  delta_s_mix  delta_d  delta_e  \
# 0                Co14Ni69P17        14.24         0.83     0.12     0.04
# 1                 C14Fe66W20        30.81         0.87     0.14    -0.13
# 2               Cu15La30Mg55         8.64         0.97     0.31    -0.13
# 3            Al87.5Ca2.5Ni10        11.30         0.44     0.21    -0.24
# 4                  B36C8Co56        35.47         0.89     0.11    -0.14
# ..                       ...          ...          ...      ...      ...
# 257             Gd55Ni25Al20        11.94         1.00     0.27    -0.19
# 258             Mg65Ni20La15        10.04         0.89     0.29    -0.14
# 259                B8Fe89Ni3        16.80         0.41     0.16    -0.02
# 260          La62Al14Cu18Ag6         8.44         1.05     0.36    -0.23
# 261  Ag53.8Mg15.4Ca23.1Cu7.7        10.40         1.16     0.19    -0.26
#
#      actual_d_max  predicted_d_max
# 0            0.00             0.02
# 1            0.00             0.00
# 2            0.00             1.77
# 3            0.00            -0.01
# 4            0.00            -0.03
# ..            ...              ...
# 257          2.00             1.36
# 258          0.50             0.44
# 259          0.00             0.02
# 260          5.00             5.77
# 261          0.50             1.22
#
# [262 rows x 7 columns]

# %%
df_test = df_test.drop(["predicted_d_max"], axis=1)
df = pd.concat([df_train, df_test], axis=0)
df = df.reset_index(drop=True)
display(df)
# Out:
#                      bmg_alloy  delta_h_mix  delta_s_mix  delta_d  delta_e  \
# 0                   Al92Nd6Ni2        10.61         0.32     0.20    -0.17
# 1     Zr26Ti10Cu8Ni8Be20Y4Mg24        13.89         1.78     0.17    -0.12
# 2              Gd55Ni22Mn3Al20        11.82         1.09     0.26    -0.18
# 3           Ag53.8Mg15.4Ca30.8        10.05         0.98     0.25    -0.28
# 4                 Ni60Nb20Zr20        19.88         0.95     0.17    -0.13
# ...                        ...          ...          ...      ...      ...
# 1316              Gd55Ni25Al20        11.94         1.00     0.27    -0.19
# 1317              Mg65Ni20La15        10.04         0.89     0.29    -0.14
# 1318                 B8Fe89Ni3        16.80         0.41     0.16    -0.02
# 1319           La62Al14Cu18Ag6         8.44         1.05     0.36    -0.23
# 1320   Ag53.8Mg15.4Ca23.1Cu7.7        10.40         1.16     0.19    -0.26
#
#       actual_d_max
# 0             0.00
# 1             5.00
# 2             2.00
# 3             0.80
# 4             0.50
# ...            ...
# 1316          2.00
# 1317          0.50
# 1318          0.00
# 1319          5.00
# 1320          0.50
#
# [1321 rows x 6 columns]

# %% [markdown]
# ## 1. Encode the bmg_alloys using an RNNs

# %%
# constants

n_elements = 118
alloy_max_len = 20
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

max_factor = max(df["actual_d_max"])

print(max_factor)
# Out:
# 30.0

# %%
# basic utility functions to calculate features

def get_elements_and_compositions(x, verbose = -1):
    # seperating atoms from composition
    s = re.sub(r'[^\w\s]','',x)
    s = re.sub('\d',' ',s)
    elements = np.array([i for i in s.split(' ') if i != ""])
    if verbose > 0:
        print('\nElements in BMG are : ', elements)

    compositions = re.findall(r"[-+]?\d*\.\d+|\d+", x)
    compositions = [float(i) for i in compositions]
    if verbose > 0:
        print('Compositions: ', compositions)
    
    return elements, compositions

def diff(alloy):
    # making ranges for each atom
    ranges = {}
    for i in alloy:
        ranges[i] = 0.88 * parameters[i]["ar"]
    # compiling scoring matrix
    score = {}
    for i in alloy:
        current_score = {}
        for j in alloy:
            if parameters[i]["ar"] < ranges[j]:
                current_score[j] = -1
            elif parameters[i]["ar"] > parameters[j]["ar"]:
                current_score[j] = 1
            else:
                current_score[j] = 0
        score[i] = current_score

    big = []
    small = []
    # separating into big and small based on scoring matrix
    for i in score:
        total_sum = 0
        for j in score[i]:
            total_sum = total_sum + score[i][j]
        if total_sum > 0:
            big.append(i)
        else:
            small.append(i)

    if len(big) == 0 or len(small) == 0:
        print(score)
    return big, small
    
# finds the paramater deltaE
def electro(elements_and_compositions, alloy):
    summation_of_product_of_composition_and_electronegativity = 0 # summation of product of composition and electro negativity
    summation_of_composition = 0 # summation of compositions
    for i in elements_and_compositions:
        if i in alloy:
            summation_of_composition = summation_of_composition + elements_and_compositions[i]
            
    for i in elements_and_compositions:
        if i in alloy:
            summation_of_product_of_composition_and_electronegativity = summation_of_product_of_composition_and_electronegativity + elements_and_compositions[i] * parameters[i]['en']
    return summation_of_product_of_composition_and_electronegativity / summation_of_composition

# finds the paramater deltaD
def comps(elements_and_compositions, alloy):
    summation_of_product_of_composition_and_atomicradii = 0 # summation of product of composition and atomic radii
    summation_of_compositions = 0 # summation of compositions
    for i in elements_and_compositions:
        if i in alloy:
            summation_of_compositions = summation_of_compositions + elements_and_compositions[i]
    for i in elements_and_compositions:
        if i in alloy:
            summation_of_product_of_composition_and_atomicradii = summation_of_product_of_composition_and_atomicradii + elements_and_compositions[i] * parameters[i]['ar']
    return summation_of_product_of_composition_and_atomicradii / summation_of_compositions

def prepare_params(alloy):
    # seperating atoms from composition
    s = re.sub(r'[^\w\s]','', alloy)
    s = re.sub('\d', ' ', s)
    elements = np.array([i for i in s.split(' ') if i in parameters]) # elements list
    # print('\nElements in BMG are : ', elements)

    compositions = re.findall(r"[-+]?\d*\.\d+|\d+", alloy)
    compositions = [float(i) for i in compositions]
    # print('Compositions: ', compositions)

    elements_and_compositions = dict(zip(elements, compositions))
    s_mix = 0
    h_mix = 0

    for i in elements_and_compositions:
        s_mix = s_mix + (elements_and_compositions[i] / 100) * (math.log((elements_and_compositions[i] / 100)))
        h_mix = h_mix + (elements_and_compositions[i] / 100) * parameters[i]['enthalphy']
    s_mix = -1*s_mix

    big, small = diff(elements)
    # print("big atoms : ", big)
    # print("small atoms : ", small)
    delta_d = (comps(elements_and_compositions,big) - comps(elements_and_compositions,small)) / (comps(elements_and_compositions,big))
    delta_e = (electro(elements_and_compositions,big) - electro(elements_and_compositions,small)) / (electro(elements_and_compositions,big) + electro(elements_and_compositions,small))
    return h_mix, s_mix, delta_d, delta_e, elements[np.argmax(compositions)]

# %%
# utility functions for encoding

# find element index from all_elements, e.g. "He" = 2
def element_to_index(element):
    try:
        atomic_number = pyasl.AtomicNo()
        return atomic_number.getAtomicNo(element)
    except:
        return "END"
    
def index_to_element(index):
    try:
        atomic_number = pyasl.AtomicNo()
        return atomic_number.getElSymbol(index)
    except:
        return "END"
    
def alloy_to_1d_tensor(alloy_str, alloy_max_len = alloy_max_len):
    tensor = torch.zeros(alloy_max_len)
    elements, compositions = get_elements_and_compositions(alloy_str)
    i = 0
    for idx in range(0, len(elements) + len(compositions), 2):
        tensor[idx] = element_to_index(elements[i])
        tensor[idx + 1] = compositions[i]
        i += 1
    return tensor

# %%
# creating the input and output data for the model

X_train = []
y_train = []

for i in range(df.shape[0]):
    X_train.append(alloy_to_1d_tensor(df.loc[i, "bmg_alloy"]))
    y_train.append(df.loc[i, "actual_d_max"] / max_factor)

X_train = torch.stack(X_train)
y_train = torch.tensor(y_train, dtype=torch.float32)

print(X_train.shape, X_train.dtype, y_train.shape, min(y_train).item(), max(y_train).item())
# Out:
# torch.Size([1321, 20]) torch.float32 torch.Size([1321]) 0.0 1.0

# %%
import torch
from torch import nn

class SequenceToSigmoid(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers):
        super().__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers=num_layers, bidirectional=True)
        self.fc = nn.Linear(hidden_size * 2, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x, _ = self.lstm(x)
        x = self.fc(x)
        x = self.sigmoid(x)
        return x

# %%
# Bidirectional LSTM
# Define hyperparameters
input_size = 20
hidden_size = 128
learning_rate = 0.001
num_epochs = 2000
batch_size = 32
num_layers = 3

# Create an instance of the model
model = SequenceToSigmoid(input_size, hidden_size, num_layers)

# Define the loss function and optimizer
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

X_train_tensor = torch.Tensor(X_train)
y_train_tensor = torch.Tensor(y_train)

# Create a PyTorch DataLoader for batching the data
train_dataset = torch.utils.data.TensorDataset(X_train_tensor, y_train_tensor)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# Set the device to use (CPU or GPU if available)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

print_every = 100
# TODO: print the average loss
# EDIT: we are printing epoch loss of batch

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    
    # Iterate over the batches of data
    for inputs, labels in train_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)
        
        # Zero the gradients
        optimizer.zero_grad()
        
        # Forward pass
        outputs = model(inputs)
        
        # Calculate the loss
        # print("output", outputs.squeeze(), "\nlabel", labels)
        loss = criterion(outputs.squeeze(), labels)
        
        # Backward pass and optimization
        loss.backward()
        optimizer.step()
        
        # Update the running loss
        running_loss += loss.item()
    
    # Calculate the average loss for the epoch
    epoch_loss = running_loss / len(train_loader)
    
    # Print the loss for this epoch
    if epoch % print_every == 0:
        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}")
# Out:
# Epoch 1/2000, Loss: 0.3104
# Epoch 101/2000, Loss: 0.1950
# Epoch 201/2000, Loss: 0.1921
# Epoch 301/2000, Loss: 0.1897
# Epoch 401/2000, Loss: 0.2017
# Epoch 501/2000, Loss: 0.1865
# Epoch 601/2000, Loss: 0.1893
# Epoch 701/2000, Loss: 0.1882
# Epoch 801/2000, Loss: 0.1853
# Epoch 901/2000, Loss: 0.1870
# Epoch 1001/2000, Loss: 0.1883
# Epoch 1101/2000, Loss: 0.1859
# Epoch 1201/2000, Loss: 0.1875
# Epoch 1301/2000, Loss: 0.1838
# Epoch 1401/2000, Loss: 0.1871
# Epoch 1501/2000, Loss: 0.1852
# Epoch 1601/2000, Loss: 0.1846
# Epoch 1701/2000, Loss: 0.1851
# Epoch 1801/2000, Loss: 0.1888
# Epoch 1901/2000, Loss: 0.1870

# %%
torch.save(model.state_dict(), "rnn_fully_trained.pt")

# %% [markdown]
# ## 2. Predict d_max and create a new dataset (dataset_rnn) to train another model on

# %%
all_rnn_output = []
for i in range(df.shape[0]):
    alloy_tensor = alloy_to_1d_tensor(df.loc[i, "bmg_alloy"])
    output = model(torch.atleast_2d(alloy_tensor))
    all_rnn_output.append(output.squeeze().item() * max_factor)
    
new_full = df

new_full["rnn_encoding"] = all_rnn_output

new_full.to_excel("dataset_rnn_full.xlsx")

# %%
display(new_full)
# Out:
#                      bmg_alloy  delta_h_mix  delta_s_mix  delta_d  delta_e  \
# 0                   Al92Nd6Ni2        10.61         0.32     0.20    -0.17
# 1     Zr26Ti10Cu8Ni8Be20Y4Mg24        13.89         1.78     0.17    -0.12
# 2              Gd55Ni22Mn3Al20        11.82         1.09     0.26    -0.18
# 3           Ag53.8Mg15.4Ca30.8        10.05         0.98     0.25    -0.28
# 4                 Ni60Nb20Zr20        19.88         0.95     0.17    -0.13
# ...                        ...          ...          ...      ...      ...
# 1316              Gd55Ni25Al20        11.94         1.00     0.27    -0.19
# 1317              Mg65Ni20La15        10.04         0.89     0.29    -0.14
# 1318                 B8Fe89Ni3        16.80         0.41     0.16    -0.02
# 1319           La62Al14Cu18Ag6         8.44         1.05     0.36    -0.23
# 1320   Ag53.8Mg15.4Ca23.1Cu7.7        10.40         1.16     0.19    -0.26
#
#       actual_d_max  rnn_encoding
# 0             0.00          0.00
# 1             5.00          4.92
# 2             2.00          2.08
# 3             0.80          0.87
# 4             0.50          0.50
# ...            ...           ...
# 1316          2.00          2.51
# 1317          0.50          0.55
# 1318          0.00          0.00
# 1319          5.00          5.18
# 1320          0.50          0.51
#
# [1321 rows x 7 columns]

# %%
df = pd.read_excel("dataset_rnn_full.xlsx", index_col=0)
df = df.drop(["bmg_alloy"], axis=1)

X_train, y_train = df.loc[:, df.columns != "actual_d_max"], pd.DataFrame(df["actual_d_max"])

X_transformer = QuantileTransformer()
y_transformer = QuantileTransformer()

transformed_X_train = pd.DataFrame(X_transformer.fit_transform(X_train), columns = X_train.columns)
transformed_y_train = pd.DataFrame(y_transformer.fit_transform(y_train), columns = y_train.columns)

model = catboost.CatBoostRegressor()
model.fit(transformed_X_train, transformed_y_train)
pickle.dump(model, open("catboost_model.pkl", "wb"))
pickle.dump(X_transformer, open("catboost_X_quantiletransformer.pkl", "wb"))
pickle.dump(y_transformer, open("catboost_y_quantiletransformer.pkl", "wb"))
# Out:
# Learning rate set to 0.042784
# 0:	learn: 0.3738436	total: 1.63ms	remaining: 1.63s
# 1:	learn: 0.3589852	total: 3.25ms	remaining: 1.62s
# 2:	learn: 0.3447191	total: 4.78ms	remaining: 1.59s
# 3:	learn: 0.3311903	total: 6.38ms	remaining: 1.59s
# 4:	learn: 0.3191896	total: 7.96ms	remaining: 1.58s
# 5:	learn: 0.3064798	total: 10.7ms	remaining: 1.78s
# 6:	learn: 0.2944641	total: 13.2ms	remaining: 1.87s
# 7:	learn: 0.2829831	total: 15.7ms	remaining: 1.95s
# 8:	learn: 0.2721050	total: 25ms	remaining: 2.76s
# 9:	learn: 0.2615380	total: 26.6ms	remaining: 2.63s
# 10:	learn: 0.2510950	total: 29.1ms	remaining: 2.62s
# 11:	learn: 0.2420239	total: 31.2ms	remaining: 2.57s
# 12:	learn: 0.2335166	total: 32.8ms	remaining: 2.49s
# 13:	learn: 0.2245795	total: 35.3ms	remaining: 2.49s
# 14:	learn: 0.2160293	total: 44.6ms	remaining: 2.93s
# 15:	learn: 0.2074530	total: 46.1ms	remaining: 2.83s
# 16:	learn: 0.1997489	total: 47.9ms	remaining: 2.77s
# 17:	learn: 0.1920720	total: 49.6ms	remaining: 2.71s
# 18:	learn: 0.1849667	total: 51.7ms	remaining: 2.67s
# 19:	learn: 0.1778685	total: 53.9ms	remaining: 2.64s
# 20:	learn: 0.1716440	total: 56.5ms	remaining: 2.63s
# 21:	learn: 0.1651255	total: 58.9ms	remaining: 2.62s
# 22:	learn: 0.1590174	total: 61.5ms	remaining: 2.61s
# 23:	learn: 0.1532172	total: 63.3ms	remaining: 2.57s
# 24:	learn: 0.1476428	total: 65.2ms	remaining: 2.54s
# 25:	learn: 0.1422517	total: 66.9ms	remaining: 2.5s
# 26:	learn: 0.1368624	total: 68.4ms	remaining: 2.46s
# 27:	learn: 0.1319069	total: 70.9ms	remaining: 2.46s
# 28:	learn: 0.1271592	total: 73.9ms	remaining: 2.47s
# 29:	learn: 0.1229426	total: 76.1ms	remaining: 2.46s
# 30:	learn: 0.1184362	total: 78.1ms	remaining: 2.44s
# 31:	learn: 0.1145170	total: 82.3ms	remaining: 2.49s
# 32:	learn: 0.1108583	total: 84.8ms	remaining: 2.48s
# 33:	learn: 0.1071154	total: 86.5ms	remaining: 2.46s
# 34:	learn: 0.1035538	total: 89.1ms	remaining: 2.46s
# 35:	learn: 0.1000016	total: 91.7ms	remaining: 2.45s
# 36:	learn: 0.0968487	total: 94.2ms	remaining: 2.45s
# 37:	learn: 0.0936993	total: 96.7ms	remaining: 2.45s
# 38:	learn: 0.0907658	total: 98.5ms	remaining: 2.43s
# 39:	learn: 0.0882014	total: 101ms	remaining: 2.42s
# 40:	learn: 0.0856969	total: 103ms	remaining: 2.41s
# 41:	learn: 0.0832846	total: 114ms	remaining: 2.61s
# 42:	learn: 0.0807876	total: 116ms	remaining: 2.59s
# 43:	learn: 0.0783480	total: 118ms	remaining: 2.57s
# 44:	learn: 0.0759508	total: 120ms	remaining: 2.55s
# 45:	learn: 0.0737446	total: 123ms	remaining: 2.54s
# 46:	learn: 0.0717699	total: 125ms	remaining: 2.53s
# 47:	learn: 0.0698253	total: 127ms	remaining: 2.52s
# 48:	learn: 0.0679524	total: 131ms	remaining: 2.54s
# 49:	learn: 0.0661853	total: 133ms	remaining: 2.53s
# 50:	learn: 0.0645008	total: 135ms	remaining: 2.52s
# 51:	learn: 0.0628942	total: 137ms	remaining: 2.49s
# 52:	learn: 0.0612965	total: 139ms	remaining: 2.48s
# 53:	learn: 0.0599243	total: 141ms	remaining: 2.47s
# 54:	learn: 0.0585996	total: 144ms	remaining: 2.47s
# 55:	learn: 0.0573387	total: 148ms	remaining: 2.5s
# 56:	learn: 0.0560363	total: 150ms	remaining: 2.48s
# 57:	learn: 0.0547718	total: 152ms	remaining: 2.47s
# 58:	learn: 0.0536613	total: 154ms	remaining: 2.46s
# 59:	learn: 0.0526972	total: 156ms	remaining: 2.44s
# 60:	learn: 0.0517328	total: 158ms	remaining: 2.43s
# 61:	learn: 0.0507190	total: 165ms	remaining: 2.5s
# 62:	learn: 0.0499491	total: 167ms	remaining: 2.48s
# 63:	learn: 0.0490535	total: 169ms	remaining: 2.48s
# 64:	learn: 0.0483702	total: 172ms	remaining: 2.48s
# 65:	learn: 0.0477200	total: 177ms	remaining: 2.5s
# 66:	learn: 0.0468741	total: 179ms	remaining: 2.49s
# 67:	learn: 0.0460891	total: 181ms	remaining: 2.48s
# 68:	learn: 0.0453604	total: 183ms	remaining: 2.47s
# 69:	learn: 0.0445802	total: 185ms	remaining: 2.45s
# 70:	learn: 0.0439966	total: 186ms	remaining: 2.44s
# 71:	learn: 0.0433136	total: 189ms	remaining: 2.43s
# 72:	learn: 0.0427531	total: 193ms	remaining: 2.45s
# 73:	learn: 0.0423892	total: 198ms	remaining: 2.48s
# 74:	learn: 0.0419626	total: 200ms	remaining: 2.46s
# 75:	learn: 0.0414020	total: 202ms	remaining: 2.46s
# 76:	learn: 0.0410926	total: 205ms	remaining: 2.45s
# 77:	learn: 0.0405730	total: 206ms	remaining: 2.44s
# 78:	learn: 0.0401040	total: 209ms	remaining: 2.43s
# 79:	learn: 0.0396468	total: 216ms	remaining: 2.49s
# 80:	learn: 0.0392590	total: 218ms	remaining: 2.48s
# 81:	learn: 0.0389705	total: 220ms	remaining: 2.46s
# 82:	learn: 0.0386842	total: 222ms	remaining: 2.45s
# 83:	learn: 0.0382553	total: 224ms	remaining: 2.44s
# 84:	learn: 0.0380087	total: 225ms	remaining: 2.43s
# 85:	learn: 0.0377909	total: 227ms	remaining: 2.42s
# 86:	learn: 0.0374632	total: 230ms	remaining: 2.42s
# 87:	learn: 0.0372960	total: 236ms	remaining: 2.44s
# 88:	learn: 0.0371173	total: 238ms	remaining: 2.43s
# 89:	learn: 0.0368538	total: 240ms	remaining: 2.43s
# 90:	learn: 0.0366793	total: 242ms	remaining: 2.42s
# 91:	learn: 0.0364550	total: 244ms	remaining: 2.41s
# 92:	learn: 0.0362530	total: 246ms	remaining: 2.4s
# 93:	learn: 0.0359981	total: 248ms	remaining: 2.39s
# 94:	learn: 0.0357566	total: 250ms	remaining: 2.38s
# 95:	learn: 0.0356109	total: 252ms	remaining: 2.37s
# 96:	learn: 0.0354733	total: 254ms	remaining: 2.36s
# 97:	learn: 0.0352347	total: 256ms	remaining: 2.36s
# 98:	learn: 0.0351367	total: 258ms	remaining: 2.35s
# 99:	learn: 0.0348521	total: 260ms	remaining: 2.34s
# 100:	learn: 0.0345196	total: 263ms	remaining: 2.34s
# 101:	learn: 0.0342497	total: 264ms	remaining: 2.33s
# 102:	learn: 0.0340632	total: 266ms	remaining: 2.32s
# 103:	learn: 0.0338267	total: 268ms	remaining: 2.31s
# 104:	learn: 0.0337268	total: 270ms	remaining: 2.3s
# 105:	learn: 0.0335157	total: 272ms	remaining: 2.29s
# 106:	learn: 0.0333128	total: 275ms	remaining: 2.29s
# 107:	learn: 0.0331531	total: 279ms	remaining: 2.3s
# 108:	learn: 0.0329427	total: 280ms	remaining: 2.29s
# 109:	learn: 0.0328813	total: 282ms	remaining: 2.28s
# 110:	learn: 0.0327598	total: 284ms	remaining: 2.28s
# 111:	learn: 0.0326489	total: 286ms	remaining: 2.27s
# 112:	learn: 0.0325942	total: 288ms	remaining: 2.26s
# 113:	learn: 0.0324025	total: 290ms	remaining: 2.25s
# 114:	learn: 0.0321455	total: 291ms	remaining: 2.24s
# 115:	learn: 0.0320877	total: 293ms	remaining: 2.23s
# 116:	learn: 0.0320439	total: 295ms	remaining: 2.23s
# 117:	learn: 0.0319473	total: 297ms	remaining: 2.22s
# 118:	learn: 0.0318035	total: 299ms	remaining: 2.21s
# 119:	learn: 0.0317176	total: 300ms	remaining: 2.2s
# 120:	learn: 0.0315736	total: 302ms	remaining: 2.19s
# 121:	learn: 0.0314029	total: 304ms	remaining: 2.19s
# 122:	learn: 0.0313612	total: 306ms	remaining: 2.18s
# 123:	learn: 0.0311351	total: 308ms	remaining: 2.18s
# 124:	learn: 0.0309591	total: 310ms	remaining: 2.17s
# 125:	learn: 0.0309159	total: 312ms	remaining: 2.16s
# 126:	learn: 0.0308515	total: 314ms	remaining: 2.15s
# 127:	learn: 0.0308085	total: 315ms	remaining: 2.15s
# 128:	learn: 0.0306717	total: 317ms	remaining: 2.14s
# 129:	learn: 0.0306117	total: 319ms	remaining: 2.13s
# 130:	learn: 0.0305782	total: 321ms	remaining: 2.13s
# 131:	learn: 0.0305395	total: 323ms	remaining: 2.12s
# 132:	learn: 0.0303929	total: 324ms	remaining: 2.12s
# 133:	learn: 0.0303655	total: 326ms	remaining: 2.11s
# 134:	learn: 0.0302962	total: 328ms	remaining: 2.1s
# 135:	learn: 0.0301547	total: 330ms	remaining: 2.09s
# 136:	learn: 0.0301191	total: 331ms	remaining: 2.09s
# 137:	learn: 0.0301013	total: 333ms	remaining: 2.08s
# 138:	learn: 0.0300610	total: 335ms	remaining: 2.07s
# 139:	learn: 0.0299410	total: 336ms	remaining: 2.07s
# 140:	learn: 0.0298820	total: 338ms	remaining: 2.06s
# 141:	learn: 0.0298137	total: 340ms	remaining: 2.05s
# 142:	learn: 0.0297017	total: 341ms	remaining: 2.04s
# 143:	learn: 0.0296214	total: 343ms	remaining: 2.04s
# 144:	learn: 0.0295249	total: 345ms	remaining: 2.03s
# 145:	learn: 0.0294889	total: 346ms	remaining: 2.03s
# 146:	learn: 0.0294499	total: 348ms	remaining: 2.02s
# 147:	learn: 0.0293840	total: 350ms	remaining: 2.01s
# 148:	learn: 0.0293592	total: 352ms	remaining: 2.01s
# 149:	learn: 0.0293259	total: 353ms	remaining: 2s
# 150:	learn: 0.0292902	total: 355ms	remaining: 2s
# 151:	learn: 0.0291161	total: 357ms	remaining: 1.99s
# 152:	learn: 0.0289167	total: 359ms	remaining: 1.99s
# 153:	learn: 0.0288288	total: 360ms	remaining: 1.98s
# 154:	learn: 0.0287877	total: 362ms	remaining: 1.97s
# 155:	learn: 0.0287537	total: 364ms	remaining: 1.97s
# 156:	learn: 0.0287193	total: 365ms	remaining: 1.96s
# 157:	learn: 0.0285621	total: 367ms	remaining: 1.96s
# 158:	learn: 0.0284590	total: 369ms	remaining: 1.95s
# 159:	learn: 0.0283390	total: 371ms	remaining: 1.95s
# 160:	learn: 0.0281772	total: 373ms	remaining: 1.94s
# 161:	learn: 0.0280594	total: 374ms	remaining: 1.94s
# 162:	learn: 0.0280164	total: 376ms	remaining: 1.93s
# 163:	learn: 0.0279864	total: 378ms	remaining: 1.93s
# 164:	learn: 0.0279540	total: 380ms	remaining: 1.92s
# 165:	learn: 0.0278261	total: 382ms	remaining: 1.92s
# 166:	learn: 0.0277992	total: 384ms	remaining: 1.91s
# 167:	learn: 0.0276343	total: 387ms	remaining: 1.92s
# 168:	learn: 0.0275805	total: 389ms	remaining: 1.91s
# 169:	learn: 0.0274833	total: 391ms	remaining: 1.91s
# 170:	learn: 0.0274331	total: 393ms	remaining: 1.9s
# 171:	learn: 0.0273984	total: 395ms	remaining: 1.9s
# 172:	learn: 0.0273004	total: 396ms	remaining: 1.89s
# 173:	learn: 0.0272344	total: 398ms	remaining: 1.89s
# 174:	learn: 0.0271893	total: 400ms	remaining: 1.89s
# 175:	learn: 0.0271620	total: 402ms	remaining: 1.88s
# 176:	learn: 0.0270541	total: 404ms	remaining: 1.88s
# 177:	learn: 0.0270345	total: 405ms	remaining: 1.87s
# 178:	learn: 0.0269447	total: 408ms	remaining: 1.87s
# 179:	learn: 0.0269158	total: 409ms	remaining: 1.86s
# 180:	learn: 0.0268852	total: 411ms	remaining: 1.86s
# 181:	learn: 0.0268548	total: 414ms	remaining: 1.86s
# 182:	learn: 0.0268249	total: 416ms	remaining: 1.86s
# 183:	learn: 0.0267063	total: 418ms	remaining: 1.85s
# 184:	learn: 0.0266597	total: 420ms	remaining: 1.85s
# 185:	learn: 0.0266312	total: 422ms	remaining: 1.85s
# 186:	learn: 0.0265871	total: 424ms	remaining: 1.84s
# 187:	learn: 0.0265291	total: 426ms	remaining: 1.84s
# 188:	learn: 0.0264436	total: 428ms	remaining: 1.84s
# 189:	learn: 0.0264180	total: 430ms	remaining: 1.83s
# 190:	learn: 0.0263838	total: 431ms	remaining: 1.83s
# 191:	learn: 0.0263399	total: 433ms	remaining: 1.82s
# 192:	learn: 0.0262996	total: 435ms	remaining: 1.82s
# 193:	learn: 0.0262620	total: 438ms	remaining: 1.82s
# 194:	learn: 0.0262331	total: 439ms	remaining: 1.81s
# 195:	learn: 0.0261964	total: 442ms	remaining: 1.81s
# 196:	learn: 0.0261726	total: 444ms	remaining: 1.81s
# 197:	learn: 0.0261292	total: 446ms	remaining: 1.81s
# 198:	learn: 0.0261040	total: 448ms	remaining: 1.8s
# 199:	learn: 0.0260848	total: 451ms	remaining: 1.8s
# 200:	learn: 0.0260122	total: 453ms	remaining: 1.8s
# 201:	learn: 0.0260009	total: 455ms	remaining: 1.79s
# 202:	learn: 0.0258842	total: 456ms	remaining: 1.79s
# 203:	learn: 0.0258288	total: 458ms	remaining: 1.79s
# 204:	learn: 0.0258104	total: 460ms	remaining: 1.78s
# 205:	learn: 0.0257876	total: 462ms	remaining: 1.78s
# 206:	learn: 0.0257492	total: 464ms	remaining: 1.78s
# 207:	learn: 0.0256587	total: 466ms	remaining: 1.77s
# 208:	learn: 0.0255517	total: 467ms	remaining: 1.77s
# 209:	learn: 0.0254804	total: 469ms	remaining: 1.76s
# 210:	learn: 0.0254714	total: 471ms	remaining: 1.76s
# 211:	learn: 0.0254102	total: 473ms	remaining: 1.76s
# 212:	learn: 0.0253240	total: 475ms	remaining: 1.75s
# 213:	learn: 0.0252730	total: 476ms	remaining: 1.75s
# 214:	learn: 0.0252246	total: 478ms	remaining: 1.75s
# 215:	learn: 0.0252058	total: 480ms	remaining: 1.74s
# 216:	learn: 0.0251838	total: 482ms	remaining: 1.74s
# 217:	learn: 0.0251631	total: 483ms	remaining: 1.73s
# 218:	learn: 0.0251342	total: 485ms	remaining: 1.73s
# 219:	learn: 0.0250529	total: 487ms	remaining: 1.73s
# 220:	learn: 0.0250407	total: 489ms	remaining: 1.72s
# 221:	learn: 0.0250076	total: 490ms	remaining: 1.72s
# 222:	learn: 0.0249800	total: 492ms	remaining: 1.72s
# 223:	learn: 0.0249051	total: 494ms	remaining: 1.71s
# 224:	learn: 0.0248656	total: 496ms	remaining: 1.71s
# 225:	learn: 0.0248373	total: 497ms	remaining: 1.7s
# 226:	learn: 0.0248041	total: 499ms	remaining: 1.7s
# 227:	learn: 0.0247871	total: 501ms	remaining: 1.7s
# 228:	learn: 0.0247591	total: 503ms	remaining: 1.69s
# 229:	learn: 0.0247422	total: 505ms	remaining: 1.69s
# 230:	learn: 0.0247176	total: 506ms	remaining: 1.69s
# 231:	learn: 0.0246857	total: 508ms	remaining: 1.68s
# 232:	learn: 0.0246678	total: 510ms	remaining: 1.68s
# 233:	learn: 0.0246409	total: 512ms	remaining: 1.68s
# 234:	learn: 0.0245881	total: 514ms	remaining: 1.67s
# 235:	learn: 0.0245514	total: 515ms	remaining: 1.67s
# 236:	learn: 0.0244952	total: 517ms	remaining: 1.67s
# 237:	learn: 0.0244796	total: 519ms	remaining: 1.66s
# 238:	learn: 0.0244558	total: 520ms	remaining: 1.66s
# 239:	learn: 0.0244241	total: 522ms	remaining: 1.65s
# 240:	learn: 0.0243534	total: 524ms	remaining: 1.65s
# 241:	learn: 0.0243158	total: 526ms	remaining: 1.65s
# 242:	learn: 0.0242949	total: 527ms	remaining: 1.64s
# 243:	learn: 0.0242877	total: 529ms	remaining: 1.64s
# 244:	learn: 0.0242726	total: 531ms	remaining: 1.63s
# 245:	learn: 0.0242572	total: 532ms	remaining: 1.63s
# 246:	learn: 0.0241574	total: 534ms	remaining: 1.63s
# 247:	learn: 0.0241350	total: 536ms	remaining: 1.62s
# 248:	learn: 0.0241088	total: 538ms	remaining: 1.62s
# 249:	learn: 0.0240905	total: 539ms	remaining: 1.62s
# 250:	learn: 0.0240722	total: 542ms	remaining: 1.62s
# 251:	learn: 0.0240526	total: 544ms	remaining: 1.61s
# 252:	learn: 0.0240214	total: 545ms	remaining: 1.61s
# 253:	learn: 0.0240022	total: 547ms	remaining: 1.61s
# 254:	learn: 0.0239853	total: 549ms	remaining: 1.6s
# 255:	learn: 0.0239569	total: 550ms	remaining: 1.6s
# 256:	learn: 0.0239387	total: 552ms	remaining: 1.6s
# 257:	learn: 0.0239024	total: 554ms	remaining: 1.59s
# 258:	learn: 0.0238843	total: 556ms	remaining: 1.59s
# 259:	learn: 0.0238200	total: 558ms	remaining: 1.59s
# 260:	learn: 0.0237854	total: 560ms	remaining: 1.58s
# 261:	learn: 0.0237511	total: 562ms	remaining: 1.58s
# 262:	learn: 0.0237261	total: 564ms	remaining: 1.58s
# 263:	learn: 0.0236731	total: 566ms	remaining: 1.58s
# 264:	learn: 0.0236641	total: 567ms	remaining: 1.57s
# 265:	learn: 0.0236469	total: 569ms	remaining: 1.57s
# 266:	learn: 0.0236302	total: 571ms	remaining: 1.57s
# 267:	learn: 0.0235365	total: 573ms	remaining: 1.56s
# 268:	learn: 0.0234935	total: 575ms	remaining: 1.56s
# 269:	learn: 0.0234611	total: 577ms	remaining: 1.56s
# 270:	learn: 0.0234531	total: 580ms	remaining: 1.56s
# 271:	learn: 0.0234345	total: 582ms	remaining: 1.56s
# 272:	learn: 0.0234091	total: 584ms	remaining: 1.55s
# 273:	learn: 0.0233712	total: 586ms	remaining: 1.55s
# 274:	learn: 0.0233304	total: 588ms	remaining: 1.55s
# 275:	learn: 0.0232968	total: 589ms	remaining: 1.55s
# 276:	learn: 0.0232603	total: 591ms	remaining: 1.54s
# 277:	learn: 0.0232503	total: 593ms	remaining: 1.54s
# 278:	learn: 0.0232371	total: 595ms	remaining: 1.54s
# 279:	learn: 0.0232309	total: 598ms	remaining: 1.54s
# 280:	learn: 0.0232226	total: 600ms	remaining: 1.53s
# 281:	learn: 0.0232096	total: 602ms	remaining: 1.53s
# 282:	learn: 0.0231744	total: 604ms	remaining: 1.53s
# 283:	learn: 0.0231355	total: 606ms	remaining: 1.53s
# 284:	learn: 0.0231042	total: 608ms	remaining: 1.52s
# 285:	learn: 0.0230843	total: 609ms	remaining: 1.52s
# 286:	learn: 0.0230674	total: 611ms	remaining: 1.52s
# 287:	learn: 0.0230615	total: 613ms	remaining: 1.51s
# 288:	learn: 0.0230322	total: 615ms	remaining: 1.51s
# 289:	learn: 0.0230051	total: 616ms	remaining: 1.51s
# 290:	learn: 0.0229686	total: 618ms	remaining: 1.5s
# 291:	learn: 0.0229627	total: 620ms	remaining: 1.5s
# 292:	learn: 0.0228599	total: 622ms	remaining: 1.5s
# 293:	learn: 0.0228207	total: 624ms	remaining: 1.5s
# 294:	learn: 0.0227997	total: 625ms	remaining: 1.49s
# 295:	learn: 0.0227776	total: 627ms	remaining: 1.49s
# 296:	learn: 0.0227269	total: 629ms	remaining: 1.49s
# 297:	learn: 0.0226981	total: 631ms	remaining: 1.49s
# 298:	learn: 0.0226264	total: 633ms	remaining: 1.48s
# 299:	learn: 0.0226207	total: 635ms	remaining: 1.48s
# 300:	learn: 0.0225947	total: 636ms	remaining: 1.48s
# 301:	learn: 0.0225565	total: 638ms	remaining: 1.47s
# 302:	learn: 0.0225343	total: 640ms	remaining: 1.47s
# 303:	learn: 0.0225092	total: 642ms	remaining: 1.47s
# 304:	learn: 0.0224849	total: 644ms	remaining: 1.47s
# 305:	learn: 0.0224492	total: 645ms	remaining: 1.46s
# 306:	learn: 0.0224279	total: 647ms	remaining: 1.46s
# 307:	learn: 0.0224130	total: 649ms	remaining: 1.46s
# 308:	learn: 0.0223675	total: 651ms	remaining: 1.46s
# 309:	learn: 0.0223382	total: 653ms	remaining: 1.45s
# 310:	learn: 0.0223182	total: 654ms	remaining: 1.45s
# 311:	learn: 0.0222991	total: 656ms	remaining: 1.45s
# 312:	learn: 0.0222694	total: 658ms	remaining: 1.44s
# 313:	learn: 0.0222509	total: 660ms	remaining: 1.44s
# 314:	learn: 0.0222104	total: 661ms	remaining: 1.44s
# 315:	learn: 0.0221810	total: 663ms	remaining: 1.44s
# 316:	learn: 0.0221756	total: 665ms	remaining: 1.43s
# 317:	learn: 0.0221591	total: 666ms	remaining: 1.43s
# 318:	learn: 0.0221537	total: 668ms	remaining: 1.43s
# 319:	learn: 0.0221211	total: 670ms	remaining: 1.42s
# 320:	learn: 0.0221159	total: 671ms	remaining: 1.42s
# 321:	learn: 0.0220554	total: 673ms	remaining: 1.42s
# 322:	learn: 0.0219891	total: 675ms	remaining: 1.41s
# 323:	learn: 0.0219840	total: 676ms	remaining: 1.41s
# 324:	learn: 0.0218954	total: 678ms	remaining: 1.41s
# 325:	learn: 0.0218754	total: 680ms	remaining: 1.41s
# 326:	learn: 0.0218633	total: 682ms	remaining: 1.4s
# 327:	learn: 0.0218463	total: 683ms	remaining: 1.4s
# 328:	learn: 0.0218173	total: 685ms	remaining: 1.4s
# 329:	learn: 0.0217992	total: 687ms	remaining: 1.4s
# 330:	learn: 0.0217861	total: 689ms	remaining: 1.39s
# 331:	learn: 0.0217046	total: 691ms	remaining: 1.39s
# 332:	learn: 0.0216901	total: 692ms	remaining: 1.39s
# 333:	learn: 0.0216791	total: 694ms	remaining: 1.38s
# 334:	learn: 0.0216620	total: 696ms	remaining: 1.38s
# 335:	learn: 0.0216571	total: 698ms	remaining: 1.38s
# 336:	learn: 0.0216411	total: 699ms	remaining: 1.38s
# 337:	learn: 0.0216233	total: 701ms	remaining: 1.37s
# 338:	learn: 0.0215884	total: 703ms	remaining: 1.37s
# 339:	learn: 0.0215658	total: 705ms	remaining: 1.37s
# 340:	learn: 0.0215374	total: 706ms	remaining: 1.36s
# 341:	learn: 0.0215278	total: 708ms	remaining: 1.36s
# 342:	learn: 0.0214970	total: 710ms	remaining: 1.36s
# 343:	learn: 0.0214829	total: 711ms	remaining: 1.36s
# 344:	learn: 0.0214641	total: 713ms	remaining: 1.35s
# 345:	learn: 0.0214492	total: 715ms	remaining: 1.35s
# 346:	learn: 0.0213745	total: 717ms	remaining: 1.35s
# 347:	learn: 0.0213510	total: 719ms	remaining: 1.35s
# 348:	learn: 0.0212949	total: 721ms	remaining: 1.34s
# 349:	learn: 0.0212842	total: 722ms	remaining: 1.34s
# 350:	learn: 0.0212686	total: 724ms	remaining: 1.34s
# 351:	learn: 0.0211934	total: 726ms	remaining: 1.34s
# 352:	learn: 0.0211788	total: 727ms	remaining: 1.33s
# 353:	learn: 0.0211608	total: 729ms	remaining: 1.33s
# 354:	learn: 0.0211458	total: 731ms	remaining: 1.33s
# 355:	learn: 0.0211187	total: 733ms	remaining: 1.32s
# 356:	learn: 0.0210732	total: 735ms	remaining: 1.32s
# 357:	learn: 0.0210021	total: 736ms	remaining: 1.32s
# 358:	learn: 0.0209877	total: 738ms	remaining: 1.32s
# 359:	learn: 0.0209787	total: 740ms	remaining: 1.31s
# 360:	learn: 0.0209637	total: 742ms	remaining: 1.31s
# 361:	learn: 0.0209476	total: 743ms	remaining: 1.31s
# 362:	learn: 0.0209388	total: 745ms	remaining: 1.31s
# 363:	learn: 0.0209246	total: 747ms	remaining: 1.3s
# 364:	learn: 0.0209097	total: 749ms	remaining: 1.3s
# 365:	learn: 0.0208826	total: 750ms	remaining: 1.3s
# 366:	learn: 0.0208727	total: 752ms	remaining: 1.3s
# 367:	learn: 0.0208642	total: 754ms	remaining: 1.29s
# 368:	learn: 0.0208505	total: 755ms	remaining: 1.29s
# 369:	learn: 0.0208419	total: 757ms	remaining: 1.29s
# 370:	learn: 0.0207750	total: 759ms	remaining: 1.29s
# 371:	learn: 0.0207647	total: 761ms	remaining: 1.28s
# 372:	learn: 0.0207386	total: 762ms	remaining: 1.28s
# 373:	learn: 0.0207304	total: 764ms	remaining: 1.28s
# 374:	learn: 0.0207020	total: 766ms	remaining: 1.28s
# 375:	learn: 0.0206894	total: 768ms	remaining: 1.27s
# 376:	learn: 0.0206636	total: 770ms	remaining: 1.27s
# 377:	learn: 0.0206493	total: 771ms	remaining: 1.27s
# 378:	learn: 0.0206226	total: 774ms	remaining: 1.27s
# 379:	learn: 0.0206118	total: 776ms	remaining: 1.27s
# 380:	learn: 0.0206039	total: 779ms	remaining: 1.26s
# 381:	learn: 0.0205875	total: 781ms	remaining: 1.26s
# 382:	learn: 0.0205710	total: 783ms	remaining: 1.26s
# 383:	learn: 0.0205066	total: 786ms	remaining: 1.26s
# 384:	learn: 0.0204911	total: 787ms	remaining: 1.26s
# 385:	learn: 0.0204649	total: 790ms	remaining: 1.25s
# 386:	learn: 0.0204519	total: 791ms	remaining: 1.25s
# 387:	learn: 0.0204373	total: 793ms	remaining: 1.25s
# 388:	learn: 0.0204185	total: 795ms	remaining: 1.25s
# 389:	learn: 0.0204109	total: 798ms	remaining: 1.25s
# 390:	learn: 0.0203475	total: 800ms	remaining: 1.25s
# 391:	learn: 0.0203356	total: 802ms	remaining: 1.24s
# 392:	learn: 0.0203112	total: 804ms	remaining: 1.24s
# 393:	learn: 0.0202909	total: 806ms	remaining: 1.24s
# 394:	learn: 0.0202655	total: 808ms	remaining: 1.24s
# 395:	learn: 0.0202059	total: 810ms	remaining: 1.23s
# 396:	learn: 0.0201984	total: 812ms	remaining: 1.23s
# 397:	learn: 0.0201907	total: 813ms	remaining: 1.23s
# 398:	learn: 0.0201775	total: 816ms	remaining: 1.23s
# 399:	learn: 0.0201525	total: 818ms	remaining: 1.23s
# 400:	learn: 0.0201301	total: 820ms	remaining: 1.23s
# 401:	learn: 0.0201212	total: 823ms	remaining: 1.22s
# 402:	learn: 0.0200944	total: 824ms	remaining: 1.22s
# 403:	learn: 0.0200872	total: 827ms	remaining: 1.22s
# 404:	learn: 0.0200342	total: 829ms	remaining: 1.22s
# 405:	learn: 0.0200025	total: 831ms	remaining: 1.22s
# 406:	learn: 0.0199955	total: 833ms	remaining: 1.21s
# 407:	learn: 0.0199388	total: 835ms	remaining: 1.21s
# 408:	learn: 0.0199184	total: 837ms	remaining: 1.21s
# 409:	learn: 0.0199076	total: 839ms	remaining: 1.21s
# 410:	learn: 0.0198996	total: 841ms	remaining: 1.2s
# 411:	learn: 0.0198428	total: 843ms	remaining: 1.2s
# 412:	learn: 0.0198219	total: 845ms	remaining: 1.2s
# 413:	learn: 0.0198141	total: 848ms	remaining: 1.2s
# 414:	learn: 0.0198065	total: 849ms	remaining: 1.2s
# 415:	learn: 0.0197501	total: 852ms	remaining: 1.2s
# 416:	learn: 0.0197213	total: 854ms	remaining: 1.19s
# 417:	learn: 0.0196673	total: 855ms	remaining: 1.19s
# 418:	learn: 0.0196407	total: 857ms	remaining: 1.19s
# 419:	learn: 0.0195903	total: 859ms	remaining: 1.19s
# 420:	learn: 0.0195821	total: 861ms	remaining: 1.18s
# 421:	learn: 0.0195612	total: 862ms	remaining: 1.18s
# 422:	learn: 0.0195077	total: 864ms	remaining: 1.18s
# 423:	learn: 0.0194859	total: 866ms	remaining: 1.18s
# 424:	learn: 0.0194742	total: 869ms	remaining: 1.18s
# 425:	learn: 0.0194457	total: 871ms	remaining: 1.17s
# 426:	learn: 0.0193929	total: 873ms	remaining: 1.17s
# 427:	learn: 0.0193497	total: 875ms	remaining: 1.17s
# 428:	learn: 0.0193051	total: 877ms	remaining: 1.17s
# 429:	learn: 0.0192857	total: 879ms	remaining: 1.16s
# 430:	learn: 0.0192699	total: 881ms	remaining: 1.16s
# 431:	learn: 0.0192484	total: 883ms	remaining: 1.16s
# 432:	learn: 0.0192387	total: 885ms	remaining: 1.16s
# 433:	learn: 0.0192291	total: 886ms	remaining: 1.16s
# 434:	learn: 0.0192096	total: 888ms	remaining: 1.15s
# 435:	learn: 0.0191925	total: 890ms	remaining: 1.15s
# 436:	learn: 0.0191512	total: 892ms	remaining: 1.15s
# 437:	learn: 0.0191390	total: 894ms	remaining: 1.15s
# 438:	learn: 0.0191243	total: 896ms	remaining: 1.14s
# 439:	learn: 0.0191134	total: 898ms	remaining: 1.14s
# 440:	learn: 0.0190845	total: 901ms	remaining: 1.14s
# 441:	learn: 0.0190713	total: 903ms	remaining: 1.14s
# 442:	learn: 0.0190565	total: 906ms	remaining: 1.14s
# 443:	learn: 0.0190401	total: 908ms	remaining: 1.14s
# 444:	learn: 0.0190252	total: 909ms	remaining: 1.13s
# 445:	learn: 0.0189976	total: 911ms	remaining: 1.13s
# 446:	learn: 0.0189579	total: 913ms	remaining: 1.13s
# 447:	learn: 0.0189402	total: 915ms	remaining: 1.13s
# 448:	learn: 0.0189309	total: 917ms	remaining: 1.13s
# 449:	learn: 0.0189111	total: 920ms	remaining: 1.12s
# 450:	learn: 0.0188925	total: 922ms	remaining: 1.12s
# 451:	learn: 0.0188795	total: 924ms	remaining: 1.12s
# 452:	learn: 0.0188424	total: 926ms	remaining: 1.12s
# 453:	learn: 0.0188038	total: 928ms	remaining: 1.11s
# 454:	learn: 0.0187926	total: 929ms	remaining: 1.11s
# 455:	learn: 0.0187694	total: 931ms	remaining: 1.11s
# 456:	learn: 0.0187552	total: 933ms	remaining: 1.11s
# 457:	learn: 0.0187326	total: 935ms	remaining: 1.11s
# 458:	learn: 0.0187233	total: 938ms	remaining: 1.1s
# 459:	learn: 0.0187098	total: 940ms	remaining: 1.1s
# 460:	learn: 0.0186880	total: 942ms	remaining: 1.1s
# 461:	learn: 0.0186715	total: 944ms	remaining: 1.1s
# 462:	learn: 0.0186583	total: 945ms	remaining: 1.1s
# 463:	learn: 0.0186333	total: 948ms	remaining: 1.09s
# 464:	learn: 0.0186042	total: 950ms	remaining: 1.09s
# 465:	learn: 0.0185826	total: 952ms	remaining: 1.09s
# 466:	learn: 0.0185618	total: 954ms	remaining: 1.09s
# 467:	learn: 0.0185226	total: 956ms	remaining: 1.09s
# 468:	learn: 0.0184780	total: 958ms	remaining: 1.08s
# 469:	learn: 0.0184629	total: 959ms	remaining: 1.08s
# 470:	learn: 0.0184271	total: 961ms	remaining: 1.08s
# 471:	learn: 0.0184149	total: 963ms	remaining: 1.08s
# 472:	learn: 0.0183697	total: 966ms	remaining: 1.08s
# 473:	learn: 0.0183531	total: 969ms	remaining: 1.07s
# 474:	learn: 0.0183188	total: 971ms	remaining: 1.07s
# 475:	learn: 0.0182857	total: 973ms	remaining: 1.07s
# 476:	learn: 0.0182582	total: 975ms	remaining: 1.07s
# 477:	learn: 0.0182439	total: 977ms	remaining: 1.07s
# 478:	learn: 0.0182351	total: 979ms	remaining: 1.06s
# 479:	learn: 0.0182181	total: 981ms	remaining: 1.06s
# 480:	learn: 0.0181993	total: 984ms	remaining: 1.06s
# 481:	learn: 0.0181907	total: 988ms	remaining: 1.06s
# 482:	learn: 0.0181838	total: 990ms	remaining: 1.06s
# 483:	learn: 0.0181650	total: 992ms	remaining: 1.06s
# 484:	learn: 0.0181400	total: 994ms	remaining: 1.05s
# 485:	learn: 0.0181322	total: 996ms	remaining: 1.05s
# 486:	learn: 0.0181088	total: 997ms	remaining: 1.05s
# 487:	learn: 0.0180906	total: 1000ms	remaining: 1.05s
# 488:	learn: 0.0180711	total: 1s	remaining: 1.05s
# 489:	learn: 0.0180399	total: 1s	remaining: 1.04s
# 490:	learn: 0.0180113	total: 1s	remaining: 1.04s
# 491:	learn: 0.0179898	total: 1.01s	remaining: 1.04s
# 492:	learn: 0.0179571	total: 1.01s	remaining: 1.04s
# 493:	learn: 0.0179435	total: 1.01s	remaining: 1.04s
# 494:	learn: 0.0179346	total: 1.01s	remaining: 1.03s
# 495:	learn: 0.0179294	total: 1.01s	remaining: 1.03s
# 496:	learn: 0.0179005	total: 1.02s	remaining: 1.03s
# 497:	learn: 0.0178958	total: 1.02s	remaining: 1.03s
# 498:	learn: 0.0178813	total: 1.02s	remaining: 1.02s
# 499:	learn: 0.0178767	total: 1.02s	remaining: 1.02s
# 500:	learn: 0.0178491	total: 1.02s	remaining: 1.02s
# 501:	learn: 0.0178201	total: 1.03s	remaining: 1.02s
# 502:	learn: 0.0178017	total: 1.03s	remaining: 1.02s
# 503:	learn: 0.0177660	total: 1.03s	remaining: 1.01s
# 504:	learn: 0.0177466	total: 1.03s	remaining: 1.01s
# 505:	learn: 0.0177371	total: 1.03s	remaining: 1.01s
# 506:	learn: 0.0177216	total: 1.03s	remaining: 1.01s
# 507:	learn: 0.0177133	total: 1.04s	remaining: 1s
# 508:	learn: 0.0176942	total: 1.04s	remaining: 1s
# 509:	learn: 0.0176763	total: 1.04s	remaining: 1s
# 510:	learn: 0.0176600	total: 1.04s	remaining: 998ms
# 511:	learn: 0.0176467	total: 1.04s	remaining: 996ms
# 512:	learn: 0.0176366	total: 1.05s	remaining: 993ms
# 513:	learn: 0.0176114	total: 1.05s	remaining: 991ms
# 514:	learn: 0.0176017	total: 1.05s	remaining: 989ms
# 515:	learn: 0.0175888	total: 1.05s	remaining: 986ms
# 516:	learn: 0.0175650	total: 1.05s	remaining: 984ms
# 517:	learn: 0.0175523	total: 1.05s	remaining: 982ms
# 518:	learn: 0.0175457	total: 1.06s	remaining: 980ms
# 519:	learn: 0.0175128	total: 1.06s	remaining: 978ms
# 520:	learn: 0.0174825	total: 1.06s	remaining: 975ms
# 521:	learn: 0.0174665	total: 1.06s	remaining: 973ms
# 522:	learn: 0.0174448	total: 1.06s	remaining: 971ms
# 523:	learn: 0.0174339	total: 1.07s	remaining: 969ms
# 524:	learn: 0.0174287	total: 1.07s	remaining: 966ms
# 525:	learn: 0.0174108	total: 1.07s	remaining: 964ms
# 526:	learn: 0.0173897	total: 1.07s	remaining: 962ms
# 527:	learn: 0.0173619	total: 1.07s	remaining: 959ms
# 528:	learn: 0.0173538	total: 1.07s	remaining: 957ms
# 529:	learn: 0.0173450	total: 1.08s	remaining: 955ms
# 530:	learn: 0.0173297	total: 1.08s	remaining: 953ms
# 531:	learn: 0.0173210	total: 1.08s	remaining: 950ms
# 532:	learn: 0.0172977	total: 1.08s	remaining: 948ms
# 533:	learn: 0.0172886	total: 1.08s	remaining: 946ms
# 534:	learn: 0.0172792	total: 1.08s	remaining: 944ms
# 535:	learn: 0.0172569	total: 1.09s	remaining: 941ms
# 536:	learn: 0.0172519	total: 1.09s	remaining: 939ms
# 537:	learn: 0.0172396	total: 1.09s	remaining: 937ms
# 538:	learn: 0.0172196	total: 1.09s	remaining: 934ms
# 539:	learn: 0.0172120	total: 1.09s	remaining: 932ms
# 540:	learn: 0.0171976	total: 1.09s	remaining: 930ms
# 541:	learn: 0.0171776	total: 1.1s	remaining: 928ms
# 542:	learn: 0.0171684	total: 1.1s	remaining: 925ms
# 543:	learn: 0.0171599	total: 1.1s	remaining: 923ms
# 544:	learn: 0.0171316	total: 1.1s	remaining: 921ms
# 545:	learn: 0.0171102	total: 1.1s	remaining: 919ms
# 546:	learn: 0.0170943	total: 1.11s	remaining: 917ms
# 547:	learn: 0.0170691	total: 1.11s	remaining: 914ms
# 548:	learn: 0.0170404	total: 1.11s	remaining: 912ms
# 549:	learn: 0.0170198	total: 1.11s	remaining: 910ms
# 550:	learn: 0.0170060	total: 1.11s	remaining: 908ms
# 551:	learn: 0.0169793	total: 1.11s	remaining: 906ms
# 552:	learn: 0.0169548	total: 1.12s	remaining: 903ms
# 553:	learn: 0.0169461	total: 1.12s	remaining: 901ms
# 554:	learn: 0.0169354	total: 1.12s	remaining: 899ms
# 555:	learn: 0.0169265	total: 1.12s	remaining: 897ms
# 556:	learn: 0.0169151	total: 1.12s	remaining: 894ms
# 557:	learn: 0.0169017	total: 1.13s	remaining: 892ms
# 558:	learn: 0.0168879	total: 1.13s	remaining: 890ms
# 559:	learn: 0.0168610	total: 1.13s	remaining: 887ms
# 560:	learn: 0.0168462	total: 1.13s	remaining: 885ms
# 561:	learn: 0.0168376	total: 1.13s	remaining: 883ms
# 562:	learn: 0.0168132	total: 1.13s	remaining: 881ms
# 563:	learn: 0.0168020	total: 1.14s	remaining: 879ms
# 564:	learn: 0.0167909	total: 1.14s	remaining: 877ms
# 565:	learn: 0.0167682	total: 1.14s	remaining: 874ms
# 566:	learn: 0.0167507	total: 1.14s	remaining: 872ms
# 567:	learn: 0.0167428	total: 1.14s	remaining: 870ms
# 568:	learn: 0.0167230	total: 1.15s	remaining: 868ms
# 569:	learn: 0.0167122	total: 1.15s	remaining: 866ms
# 570:	learn: 0.0167011	total: 1.15s	remaining: 864ms
# 571:	learn: 0.0166947	total: 1.15s	remaining: 862ms
# 572:	learn: 0.0166736	total: 1.15s	remaining: 860ms
# 573:	learn: 0.0166521	total: 1.16s	remaining: 858ms
# 574:	learn: 0.0166481	total: 1.16s	remaining: 855ms
# 575:	learn: 0.0166317	total: 1.16s	remaining: 854ms
# 576:	learn: 0.0166279	total: 1.16s	remaining: 852ms
# 577:	learn: 0.0166066	total: 1.16s	remaining: 850ms
# 578:	learn: 0.0165913	total: 1.17s	remaining: 848ms
# 579:	learn: 0.0165728	total: 1.17s	remaining: 846ms
# 580:	learn: 0.0165678	total: 1.17s	remaining: 844ms
# 581:	learn: 0.0165536	total: 1.17s	remaining: 842ms
# 582:	learn: 0.0165362	total: 1.17s	remaining: 840ms
# 583:	learn: 0.0165206	total: 1.18s	remaining: 838ms
# 584:	learn: 0.0165135	total: 1.18s	remaining: 836ms
# 585:	learn: 0.0165012	total: 1.18s	remaining: 833ms
# 586:	learn: 0.0164900	total: 1.18s	remaining: 831ms
# 587:	learn: 0.0164775	total: 1.18s	remaining: 829ms
# 588:	learn: 0.0164716	total: 1.19s	remaining: 827ms
# 589:	learn: 0.0164658	total: 1.19s	remaining: 825ms
# 590:	learn: 0.0164521	total: 1.19s	remaining: 824ms
# 591:	learn: 0.0164424	total: 1.19s	remaining: 823ms
# 592:	learn: 0.0164344	total: 1.2s	remaining: 821ms
# 593:	learn: 0.0164246	total: 1.2s	remaining: 818ms
# 594:	learn: 0.0164025	total: 1.2s	remaining: 816ms
# 595:	learn: 0.0163830	total: 1.2s	remaining: 814ms
# 596:	learn: 0.0163571	total: 1.2s	remaining: 813ms
# 597:	learn: 0.0163316	total: 1.21s	remaining: 812ms
# 598:	learn: 0.0163238	total: 1.21s	remaining: 810ms
# 599:	learn: 0.0163154	total: 1.21s	remaining: 808ms
# 600:	learn: 0.0163086	total: 1.21s	remaining: 806ms
# 601:	learn: 0.0162843	total: 1.22s	remaining: 804ms
# 602:	learn: 0.0162783	total: 1.22s	remaining: 802ms
# 603:	learn: 0.0162557	total: 1.22s	remaining: 799ms
# 604:	learn: 0.0162429	total: 1.22s	remaining: 798ms
# 605:	learn: 0.0162297	total: 1.22s	remaining: 796ms
# 606:	learn: 0.0162246	total: 1.23s	remaining: 794ms
# 607:	learn: 0.0162165	total: 1.23s	remaining: 792ms
# 608:	learn: 0.0161985	total: 1.23s	remaining: 790ms
# 609:	learn: 0.0161949	total: 1.23s	remaining: 788ms
# 610:	learn: 0.0161668	total: 1.23s	remaining: 785ms
# 611:	learn: 0.0161488	total: 1.24s	remaining: 783ms
# 612:	learn: 0.0161256	total: 1.24s	remaining: 781ms
# 613:	learn: 0.0161204	total: 1.24s	remaining: 779ms
# 614:	learn: 0.0161129	total: 1.24s	remaining: 777ms
# 615:	learn: 0.0161024	total: 1.24s	remaining: 775ms
# 616:	learn: 0.0160873	total: 1.24s	remaining: 773ms
# 617:	learn: 0.0160692	total: 1.25s	remaining: 771ms
# 618:	learn: 0.0160614	total: 1.25s	remaining: 769ms
# 619:	learn: 0.0160538	total: 1.25s	remaining: 767ms
# 620:	learn: 0.0160445	total: 1.25s	remaining: 765ms
# 621:	learn: 0.0160365	total: 1.25s	remaining: 763ms
# 622:	learn: 0.0160183	total: 1.26s	remaining: 761ms
# 623:	learn: 0.0160082	total: 1.26s	remaining: 759ms
# 624:	learn: 0.0159826	total: 1.26s	remaining: 757ms
# 625:	learn: 0.0159514	total: 1.26s	remaining: 755ms
# 626:	learn: 0.0159465	total: 1.26s	remaining: 753ms
# 627:	learn: 0.0159420	total: 1.27s	remaining: 750ms
# 628:	learn: 0.0159309	total: 1.27s	remaining: 748ms
# 629:	learn: 0.0159128	total: 1.27s	remaining: 746ms
# 630:	learn: 0.0159032	total: 1.27s	remaining: 744ms
# 631:	learn: 0.0158989	total: 1.27s	remaining: 742ms
# 632:	learn: 0.0158880	total: 1.28s	remaining: 740ms
# 633:	learn: 0.0158798	total: 1.28s	remaining: 738ms
# 634:	learn: 0.0158626	total: 1.28s	remaining: 736ms
# 635:	learn: 0.0158546	total: 1.28s	remaining: 734ms
# 636:	learn: 0.0158384	total: 1.28s	remaining: 732ms
# 637:	learn: 0.0158279	total: 1.29s	remaining: 730ms
# 638:	learn: 0.0158007	total: 1.29s	remaining: 728ms
# 639:	learn: 0.0157866	total: 1.29s	remaining: 726ms
# 640:	learn: 0.0157718	total: 1.29s	remaining: 724ms
# 641:	learn: 0.0157498	total: 1.29s	remaining: 721ms
# 642:	learn: 0.0157453	total: 1.29s	remaining: 719ms
# 643:	learn: 0.0157329	total: 1.3s	remaining: 717ms
# 644:	learn: 0.0157256	total: 1.3s	remaining: 715ms
# 645:	learn: 0.0157092	total: 1.3s	remaining: 713ms
# 646:	learn: 0.0157021	total: 1.3s	remaining: 711ms
# 647:	learn: 0.0156900	total: 1.3s	remaining: 709ms
# 648:	learn: 0.0156680	total: 1.31s	remaining: 707ms
# 649:	learn: 0.0156608	total: 1.31s	remaining: 705ms
# 650:	learn: 0.0156316	total: 1.31s	remaining: 703ms
# 651:	learn: 0.0156246	total: 1.31s	remaining: 701ms
# 652:	learn: 0.0156007	total: 1.31s	remaining: 699ms
# 653:	learn: 0.0155830	total: 1.32s	remaining: 697ms
# 654:	learn: 0.0155556	total: 1.32s	remaining: 695ms
# 655:	learn: 0.0155482	total: 1.32s	remaining: 693ms
# 656:	learn: 0.0155415	total: 1.32s	remaining: 690ms
# 657:	learn: 0.0155117	total: 1.32s	remaining: 688ms
# 658:	learn: 0.0155081	total: 1.33s	remaining: 686ms
# 659:	learn: 0.0154905	total: 1.33s	remaining: 684ms
# 660:	learn: 0.0154732	total: 1.33s	remaining: 682ms
# 661:	learn: 0.0154631	total: 1.33s	remaining: 680ms
# 662:	learn: 0.0154368	total: 1.33s	remaining: 678ms
# 663:	learn: 0.0154220	total: 1.33s	remaining: 676ms
# 664:	learn: 0.0154053	total: 1.34s	remaining: 674ms
# 665:	learn: 0.0153774	total: 1.34s	remaining: 672ms
# 666:	learn: 0.0153559	total: 1.34s	remaining: 669ms
# 667:	learn: 0.0153509	total: 1.34s	remaining: 668ms
# 668:	learn: 0.0153379	total: 1.34s	remaining: 665ms
# 669:	learn: 0.0153128	total: 1.35s	remaining: 664ms
# 670:	learn: 0.0152854	total: 1.35s	remaining: 662ms
# 671:	learn: 0.0152720	total: 1.35s	remaining: 660ms
# 672:	learn: 0.0152533	total: 1.35s	remaining: 658ms
# 673:	learn: 0.0152392	total: 1.36s	remaining: 657ms
# 674:	learn: 0.0152162	total: 1.36s	remaining: 655ms
# 675:	learn: 0.0152087	total: 1.36s	remaining: 653ms
# 676:	learn: 0.0151912	total: 1.36s	remaining: 651ms
# 677:	learn: 0.0151753	total: 1.37s	remaining: 649ms
# 678:	learn: 0.0151710	total: 1.37s	remaining: 647ms
# 679:	learn: 0.0151585	total: 1.37s	remaining: 645ms
# 680:	learn: 0.0151466	total: 1.37s	remaining: 643ms
# 681:	learn: 0.0151351	total: 1.37s	remaining: 641ms
# 682:	learn: 0.0151184	total: 1.38s	remaining: 639ms
# 683:	learn: 0.0151049	total: 1.38s	remaining: 637ms
# 684:	learn: 0.0150949	total: 1.38s	remaining: 635ms
# 685:	learn: 0.0150881	total: 1.38s	remaining: 633ms
# 686:	learn: 0.0150656	total: 1.39s	remaining: 631ms
# 687:	learn: 0.0150528	total: 1.39s	remaining: 629ms
# 688:	learn: 0.0150392	total: 1.39s	remaining: 627ms
# 689:	learn: 0.0150241	total: 1.39s	remaining: 625ms
# 690:	learn: 0.0150025	total: 1.39s	remaining: 623ms
# 691:	learn: 0.0149874	total: 1.4s	remaining: 621ms
# 692:	learn: 0.0149778	total: 1.4s	remaining: 619ms
# 693:	learn: 0.0149638	total: 1.4s	remaining: 617ms
# 694:	learn: 0.0149505	total: 1.4s	remaining: 615ms
# 695:	learn: 0.0149359	total: 1.4s	remaining: 613ms
# 696:	learn: 0.0149243	total: 1.41s	remaining: 611ms
# 697:	learn: 0.0149068	total: 1.41s	remaining: 609ms
# 698:	learn: 0.0148911	total: 1.41s	remaining: 607ms
# 699:	learn: 0.0148771	total: 1.41s	remaining: 605ms
# 700:	learn: 0.0148545	total: 1.41s	remaining: 603ms
# 701:	learn: 0.0148483	total: 1.42s	remaining: 601ms
# 702:	learn: 0.0148255	total: 1.42s	remaining: 599ms
# 703:	learn: 0.0148187	total: 1.42s	remaining: 597ms
# 704:	learn: 0.0147939	total: 1.42s	remaining: 595ms
# 705:	learn: 0.0147865	total: 1.42s	remaining: 593ms
# 706:	learn: 0.0147789	total: 1.43s	remaining: 591ms
# 707:	learn: 0.0147670	total: 1.43s	remaining: 589ms
# 708:	learn: 0.0147635	total: 1.43s	remaining: 587ms
# 709:	learn: 0.0147397	total: 1.43s	remaining: 585ms
# 710:	learn: 0.0147288	total: 1.43s	remaining: 583ms
# 711:	learn: 0.0147204	total: 1.44s	remaining: 581ms
# 712:	learn: 0.0147078	total: 1.44s	remaining: 579ms
# 713:	learn: 0.0146903	total: 1.44s	remaining: 577ms
# 714:	learn: 0.0146750	total: 1.44s	remaining: 575ms
# 715:	learn: 0.0146629	total: 1.44s	remaining: 573ms
# 716:	learn: 0.0146483	total: 1.45s	remaining: 571ms
# 717:	learn: 0.0146400	total: 1.45s	remaining: 569ms
# 718:	learn: 0.0146319	total: 1.45s	remaining: 567ms
# 719:	learn: 0.0146265	total: 1.45s	remaining: 564ms
# 720:	learn: 0.0146174	total: 1.45s	remaining: 562ms
# 721:	learn: 0.0146121	total: 1.46s	remaining: 560ms
# 722:	learn: 0.0146070	total: 1.46s	remaining: 558ms
# 723:	learn: 0.0145995	total: 1.46s	remaining: 556ms
# 724:	learn: 0.0145929	total: 1.46s	remaining: 554ms
# 725:	learn: 0.0145856	total: 1.46s	remaining: 552ms
# 726:	learn: 0.0145813	total: 1.46s	remaining: 550ms
# 727:	learn: 0.0145725	total: 1.47s	remaining: 548ms
# 728:	learn: 0.0145683	total: 1.47s	remaining: 546ms
# 729:	learn: 0.0145643	total: 1.47s	remaining: 544ms
# 730:	learn: 0.0145505	total: 1.47s	remaining: 541ms
# 731:	learn: 0.0145367	total: 1.47s	remaining: 539ms
# 732:	learn: 0.0145246	total: 1.48s	remaining: 537ms
# 733:	learn: 0.0145103	total: 1.48s	remaining: 535ms
# 734:	learn: 0.0145062	total: 1.48s	remaining: 533ms
# 735:	learn: 0.0145023	total: 1.48s	remaining: 531ms
# 736:	learn: 0.0144913	total: 1.48s	remaining: 529ms
# 737:	learn: 0.0144875	total: 1.48s	remaining: 527ms
# 738:	learn: 0.0144776	total: 1.49s	remaining: 525ms
# 739:	learn: 0.0144661	total: 1.49s	remaining: 523ms
# 740:	learn: 0.0144557	total: 1.49s	remaining: 521ms
# 741:	learn: 0.0144480	total: 1.49s	remaining: 519ms
# 742:	learn: 0.0144345	total: 1.49s	remaining: 517ms
# 743:	learn: 0.0144231	total: 1.5s	remaining: 515ms
# 744:	learn: 0.0144135	total: 1.5s	remaining: 513ms
# 745:	learn: 0.0143900	total: 1.5s	remaining: 511ms
# 746:	learn: 0.0143735	total: 1.5s	remaining: 509ms
# 747:	learn: 0.0143624	total: 1.5s	remaining: 507ms
# 748:	learn: 0.0143597	total: 1.51s	remaining: 505ms
# 749:	learn: 0.0143500	total: 1.51s	remaining: 503ms
# 750:	learn: 0.0143392	total: 1.51s	remaining: 501ms
# 751:	learn: 0.0143282	total: 1.51s	remaining: 498ms
# 752:	learn: 0.0143213	total: 1.51s	remaining: 496ms
# 753:	learn: 0.0143024	total: 1.51s	remaining: 494ms
# 754:	learn: 0.0142830	total: 1.52s	remaining: 492ms
# 755:	learn: 0.0142694	total: 1.52s	remaining: 490ms
# 756:	learn: 0.0142659	total: 1.52s	remaining: 488ms
# 757:	learn: 0.0142565	total: 1.52s	remaining: 486ms
# 758:	learn: 0.0142352	total: 1.52s	remaining: 484ms
# 759:	learn: 0.0142290	total: 1.53s	remaining: 482ms
# 760:	learn: 0.0142065	total: 1.53s	remaining: 480ms
# 761:	learn: 0.0141912	total: 1.53s	remaining: 478ms
# 762:	learn: 0.0141812	total: 1.53s	remaining: 476ms
# 763:	learn: 0.0141777	total: 1.53s	remaining: 474ms
# 764:	learn: 0.0141716	total: 1.53s	remaining: 472ms
# 765:	learn: 0.0141555	total: 1.54s	remaining: 470ms
# 766:	learn: 0.0141350	total: 1.54s	remaining: 468ms
# 767:	learn: 0.0141156	total: 1.54s	remaining: 466ms
# 768:	learn: 0.0141019	total: 1.54s	remaining: 464ms
# 769:	learn: 0.0140907	total: 1.55s	remaining: 462ms
# 770:	learn: 0.0140783	total: 1.55s	remaining: 460ms
# 771:	learn: 0.0140661	total: 1.55s	remaining: 458ms
# 772:	learn: 0.0140569	total: 1.55s	remaining: 456ms
# 773:	learn: 0.0140423	total: 1.55s	remaining: 454ms
# 774:	learn: 0.0140381	total: 1.56s	remaining: 452ms
# 775:	learn: 0.0140336	total: 1.56s	remaining: 450ms
# 776:	learn: 0.0140312	total: 1.56s	remaining: 448ms
# 777:	learn: 0.0140253	total: 1.56s	remaining: 446ms
# 778:	learn: 0.0140190	total: 1.56s	remaining: 444ms
# 779:	learn: 0.0140067	total: 1.57s	remaining: 442ms
# 780:	learn: 0.0139959	total: 1.57s	remaining: 440ms
# 781:	learn: 0.0139896	total: 1.57s	remaining: 438ms
# 782:	learn: 0.0139779	total: 1.57s	remaining: 436ms
# 783:	learn: 0.0139696	total: 1.57s	remaining: 434ms
# 784:	learn: 0.0139636	total: 1.57s	remaining: 432ms
# 785:	learn: 0.0139502	total: 1.58s	remaining: 430ms
# 786:	learn: 0.0139394	total: 1.58s	remaining: 428ms
# 787:	learn: 0.0139301	total: 1.58s	remaining: 426ms
# 788:	learn: 0.0139200	total: 1.58s	remaining: 423ms
# 789:	learn: 0.0139157	total: 1.58s	remaining: 421ms
# 790:	learn: 0.0139054	total: 1.59s	remaining: 419ms
# 791:	learn: 0.0138970	total: 1.59s	remaining: 417ms
# 792:	learn: 0.0138806	total: 1.59s	remaining: 415ms
# 793:	learn: 0.0138764	total: 1.59s	remaining: 413ms
# 794:	learn: 0.0138659	total: 1.59s	remaining: 411ms
# 795:	learn: 0.0138582	total: 1.6s	remaining: 409ms
# 796:	learn: 0.0138480	total: 1.6s	remaining: 407ms
# 797:	learn: 0.0138363	total: 1.6s	remaining: 405ms
# 798:	learn: 0.0138236	total: 1.6s	remaining: 403ms
# 799:	learn: 0.0138011	total: 1.6s	remaining: 401ms
# 800:	learn: 0.0137942	total: 1.6s	remaining: 399ms
# 801:	learn: 0.0137831	total: 1.61s	remaining: 397ms
# 802:	learn: 0.0137722	total: 1.61s	remaining: 395ms
# 803:	learn: 0.0137638	total: 1.61s	remaining: 393ms
# 804:	learn: 0.0137486	total: 1.61s	remaining: 391ms
# 805:	learn: 0.0137454	total: 1.61s	remaining: 389ms
# 806:	learn: 0.0137341	total: 1.62s	remaining: 387ms
# 807:	learn: 0.0137279	total: 1.62s	remaining: 384ms
# 808:	learn: 0.0137190	total: 1.62s	remaining: 382ms
# 809:	learn: 0.0137101	total: 1.62s	remaining: 380ms
# 810:	learn: 0.0136925	total: 1.62s	remaining: 378ms
# 811:	learn: 0.0136893	total: 1.62s	remaining: 376ms
# 812:	learn: 0.0136697	total: 1.63s	remaining: 374ms
# 813:	learn: 0.0136616	total: 1.63s	remaining: 372ms
# 814:	learn: 0.0136460	total: 1.63s	remaining: 370ms
# 815:	learn: 0.0136352	total: 1.63s	remaining: 368ms
# 816:	learn: 0.0136248	total: 1.63s	remaining: 366ms
# 817:	learn: 0.0136128	total: 1.64s	remaining: 364ms
# 818:	learn: 0.0136023	total: 1.64s	remaining: 362ms
# 819:	learn: 0.0135985	total: 1.64s	remaining: 360ms
# 820:	learn: 0.0135949	total: 1.64s	remaining: 358ms
# 821:	learn: 0.0135911	total: 1.64s	remaining: 356ms
# 822:	learn: 0.0135736	total: 1.65s	remaining: 354ms
# 823:	learn: 0.0135684	total: 1.65s	remaining: 352ms
# 824:	learn: 0.0135561	total: 1.65s	remaining: 350ms
# 825:	learn: 0.0135494	total: 1.65s	remaining: 348ms
# 826:	learn: 0.0135361	total: 1.65s	remaining: 346ms
# 827:	learn: 0.0135291	total: 1.66s	remaining: 344ms
# 828:	learn: 0.0135215	total: 1.66s	remaining: 342ms
# 829:	learn: 0.0135088	total: 1.66s	remaining: 340ms
# 830:	learn: 0.0134978	total: 1.66s	remaining: 338ms
# 831:	learn: 0.0134871	total: 1.66s	remaining: 336ms
# 832:	learn: 0.0134715	total: 1.67s	remaining: 334ms
# 833:	learn: 0.0134643	total: 1.67s	remaining: 332ms
# 834:	learn: 0.0134544	total: 1.67s	remaining: 330ms
# 835:	learn: 0.0134397	total: 1.67s	remaining: 328ms
# 836:	learn: 0.0134335	total: 1.67s	remaining: 326ms
# 837:	learn: 0.0134280	total: 1.68s	remaining: 324ms
# 838:	learn: 0.0134184	total: 1.68s	remaining: 322ms
# 839:	learn: 0.0134149	total: 1.68s	remaining: 320ms
# 840:	learn: 0.0133974	total: 1.68s	remaining: 318ms
# 841:	learn: 0.0133939	total: 1.68s	remaining: 316ms
# 842:	learn: 0.0133913	total: 1.68s	remaining: 314ms
# 843:	learn: 0.0133842	total: 1.69s	remaining: 312ms
# 844:	learn: 0.0133813	total: 1.69s	remaining: 310ms
# 845:	learn: 0.0133676	total: 1.69s	remaining: 308ms
# 846:	learn: 0.0133592	total: 1.69s	remaining: 306ms
# 847:	learn: 0.0133508	total: 1.69s	remaining: 304ms
# 848:	learn: 0.0133380	total: 1.7s	remaining: 302ms
# 849:	learn: 0.0133351	total: 1.7s	remaining: 300ms
# 850:	learn: 0.0133333	total: 1.7s	remaining: 298ms
# 851:	learn: 0.0133274	total: 1.7s	remaining: 296ms
# 852:	learn: 0.0133194	total: 1.7s	remaining: 294ms
# 853:	learn: 0.0133077	total: 1.71s	remaining: 292ms
# 854:	learn: 0.0132990	total: 1.71s	remaining: 290ms
# 855:	learn: 0.0132820	total: 1.71s	remaining: 288ms
# 856:	learn: 0.0132787	total: 1.71s	remaining: 286ms
# 857:	learn: 0.0132751	total: 1.71s	remaining: 283ms
# 858:	learn: 0.0132639	total: 1.71s	remaining: 281ms
# 859:	learn: 0.0132529	total: 1.72s	remaining: 279ms
# 860:	learn: 0.0132503	total: 1.72s	remaining: 277ms
# 861:	learn: 0.0132314	total: 1.72s	remaining: 275ms
# 862:	learn: 0.0132285	total: 1.72s	remaining: 273ms
# 863:	learn: 0.0132140	total: 1.72s	remaining: 271ms
# 864:	learn: 0.0132019	total: 1.73s	remaining: 269ms
# 865:	learn: 0.0131994	total: 1.73s	remaining: 267ms
# 866:	learn: 0.0131875	total: 1.73s	remaining: 265ms
# 867:	learn: 0.0131771	total: 1.73s	remaining: 263ms
# 868:	learn: 0.0131674	total: 1.73s	remaining: 261ms
# 869:	learn: 0.0131646	total: 1.74s	remaining: 259ms
# 870:	learn: 0.0131470	total: 1.74s	remaining: 257ms
# 871:	learn: 0.0131388	total: 1.74s	remaining: 255ms
# 872:	learn: 0.0131288	total: 1.74s	remaining: 253ms
# 873:	learn: 0.0131254	total: 1.74s	remaining: 251ms
# 874:	learn: 0.0131136	total: 1.75s	remaining: 249ms
# 875:	learn: 0.0131082	total: 1.75s	remaining: 247ms
# 876:	learn: 0.0131029	total: 1.75s	remaining: 245ms
# 877:	learn: 0.0130871	total: 1.75s	remaining: 244ms
# 878:	learn: 0.0130767	total: 1.75s	remaining: 242ms
# 879:	learn: 0.0130715	total: 1.76s	remaining: 240ms
# 880:	learn: 0.0130614	total: 1.76s	remaining: 238ms
# 881:	learn: 0.0130535	total: 1.76s	remaining: 236ms
# 882:	learn: 0.0130388	total: 1.76s	remaining: 234ms
# 883:	learn: 0.0130286	total: 1.76s	remaining: 232ms
# 884:	learn: 0.0130172	total: 1.77s	remaining: 230ms
# 885:	learn: 0.0130073	total: 1.77s	remaining: 228ms
# 886:	learn: 0.0129976	total: 1.77s	remaining: 226ms
# 887:	learn: 0.0129867	total: 1.77s	remaining: 224ms
# 888:	learn: 0.0129801	total: 1.77s	remaining: 221ms
# 889:	learn: 0.0129698	total: 1.77s	remaining: 219ms
# 890:	learn: 0.0129531	total: 1.78s	remaining: 217ms
# 891:	learn: 0.0129372	total: 1.78s	remaining: 215ms
# 892:	learn: 0.0129332	total: 1.78s	remaining: 213ms
# 893:	learn: 0.0129284	total: 1.78s	remaining: 211ms
# 894:	learn: 0.0129206	total: 1.78s	remaining: 209ms
# 895:	learn: 0.0129110	total: 1.79s	remaining: 207ms
# 896:	learn: 0.0128978	total: 1.79s	remaining: 205ms
# 897:	learn: 0.0128743	total: 1.79s	remaining: 203ms
# 898:	learn: 0.0128590	total: 1.79s	remaining: 201ms
# 899:	learn: 0.0128433	total: 1.79s	remaining: 199ms
# 900:	learn: 0.0128330	total: 1.79s	remaining: 197ms
# 901:	learn: 0.0128226	total: 1.8s	remaining: 195ms
# 902:	learn: 0.0128186	total: 1.8s	remaining: 193ms
# 903:	learn: 0.0128006	total: 1.8s	remaining: 191ms
# 904:	learn: 0.0127817	total: 1.8s	remaining: 189ms
# 905:	learn: 0.0127693	total: 1.8s	remaining: 187ms
# 906:	learn: 0.0127621	total: 1.81s	remaining: 185ms
# 907:	learn: 0.0127581	total: 1.81s	remaining: 183ms
# 908:	learn: 0.0127470	total: 1.81s	remaining: 181ms
# 909:	learn: 0.0127284	total: 1.81s	remaining: 179ms
# 910:	learn: 0.0127190	total: 1.81s	remaining: 177ms
# 911:	learn: 0.0127162	total: 1.82s	remaining: 175ms
# 912:	learn: 0.0127052	total: 1.82s	remaining: 173ms
# 913:	learn: 0.0126950	total: 1.82s	remaining: 171ms
# 914:	learn: 0.0126881	total: 1.82s	remaining: 169ms
# 915:	learn: 0.0126679	total: 1.82s	remaining: 167ms
# 916:	learn: 0.0126552	total: 1.82s	remaining: 165ms
# 917:	learn: 0.0126452	total: 1.83s	remaining: 163ms
# 918:	learn: 0.0126324	total: 1.83s	remaining: 161ms
# 919:	learn: 0.0126233	total: 1.83s	remaining: 159ms
# 920:	learn: 0.0126054	total: 1.83s	remaining: 157ms
# 921:	learn: 0.0125891	total: 1.83s	remaining: 155ms
# 922:	learn: 0.0125859	total: 1.83s	remaining: 153ms
# 923:	learn: 0.0125797	total: 1.84s	remaining: 151ms
# 924:	learn: 0.0125774	total: 1.84s	remaining: 149ms
# 925:	learn: 0.0125709	total: 1.84s	remaining: 147ms
# 926:	learn: 0.0125588	total: 1.84s	remaining: 145ms
# 927:	learn: 0.0125424	total: 1.84s	remaining: 143ms
# 928:	learn: 0.0125377	total: 1.85s	remaining: 141ms
# 929:	learn: 0.0125255	total: 1.85s	remaining: 139ms
# 930:	learn: 0.0125160	total: 1.85s	remaining: 137ms
# 931:	learn: 0.0125076	total: 1.85s	remaining: 135ms
# 932:	learn: 0.0124905	total: 1.85s	remaining: 133ms
# 933:	learn: 0.0124797	total: 1.86s	remaining: 131ms
# 934:	learn: 0.0124739	total: 1.86s	remaining: 129ms
# 935:	learn: 0.0124649	total: 1.86s	remaining: 127ms
# 936:	learn: 0.0124597	total: 1.86s	remaining: 125ms
# 937:	learn: 0.0124580	total: 1.86s	remaining: 123ms
# 938:	learn: 0.0124363	total: 1.86s	remaining: 121ms
# 939:	learn: 0.0124241	total: 1.87s	remaining: 119ms
# 940:	learn: 0.0124190	total: 1.87s	remaining: 117ms
# 941:	learn: 0.0124099	total: 1.87s	remaining: 115ms
# 942:	learn: 0.0124015	total: 1.87s	remaining: 113ms
# 943:	learn: 0.0123966	total: 1.87s	remaining: 111ms
# 944:	learn: 0.0123809	total: 1.88s	remaining: 109ms
# 945:	learn: 0.0123758	total: 1.88s	remaining: 107ms
# 946:	learn: 0.0123596	total: 1.88s	remaining: 105ms
# 947:	learn: 0.0123517	total: 1.88s	remaining: 103ms
# 948:	learn: 0.0123391	total: 1.88s	remaining: 101ms
# 949:	learn: 0.0123301	total: 1.89s	remaining: 99.3ms
# 950:	learn: 0.0123263	total: 1.89s	remaining: 97.3ms
# 951:	learn: 0.0123109	total: 1.89s	remaining: 95.3ms
# 952:	learn: 0.0122956	total: 1.89s	remaining: 93.3ms
# 953:	learn: 0.0122805	total: 1.89s	remaining: 91.3ms
# 954:	learn: 0.0122738	total: 1.89s	remaining: 89.3ms
# 955:	learn: 0.0122709	total: 1.9s	remaining: 87.3ms
# 956:	learn: 0.0122615	total: 1.9s	remaining: 85.3ms
# 957:	learn: 0.0122525	total: 1.9s	remaining: 83.3ms
# 958:	learn: 0.0122495	total: 1.9s	remaining: 81.3ms
# 959:	learn: 0.0122460	total: 1.9s	remaining: 79.3ms
# 960:	learn: 0.0122310	total: 1.9s	remaining: 77.3ms
# 961:	learn: 0.0122154	total: 1.91s	remaining: 75.3ms
# 962:	learn: 0.0122006	total: 1.91s	remaining: 73.3ms
# 963:	learn: 0.0121855	total: 1.91s	remaining: 71.3ms
# 964:	learn: 0.0121713	total: 1.91s	remaining: 69.3ms
# 965:	learn: 0.0121666	total: 1.91s	remaining: 67.3ms
# 966:	learn: 0.0121505	total: 1.92s	remaining: 65.4ms
# 967:	learn: 0.0121281	total: 1.92s	remaining: 63.4ms
# 968:	learn: 0.0121199	total: 1.92s	remaining: 61.4ms
# 969:	learn: 0.0121051	total: 1.92s	remaining: 59.4ms
# 970:	learn: 0.0120960	total: 1.92s	remaining: 57.4ms
# 971:	learn: 0.0120917	total: 1.92s	remaining: 55.4ms
# 972:	learn: 0.0120737	total: 1.93s	remaining: 53.4ms
# 973:	learn: 0.0120584	total: 1.93s	remaining: 51.5ms
# 974:	learn: 0.0120505	total: 1.93s	remaining: 49.5ms
# 975:	learn: 0.0120477	total: 1.93s	remaining: 47.5ms
# 976:	learn: 0.0120387	total: 1.93s	remaining: 45.5ms
# 977:	learn: 0.0120230	total: 1.94s	remaining: 43.6ms
# 978:	learn: 0.0120196	total: 1.94s	remaining: 41.6ms
# 979:	learn: 0.0120139	total: 1.94s	remaining: 39.6ms
# 980:	learn: 0.0120107	total: 1.94s	remaining: 37.6ms
# 981:	learn: 0.0120045	total: 1.94s	remaining: 35.6ms
# 982:	learn: 0.0120019	total: 1.95s	remaining: 33.7ms
# 983:	learn: 0.0119917	total: 1.95s	remaining: 31.7ms
# 984:	learn: 0.0119891	total: 1.95s	remaining: 29.7ms
# 985:	learn: 0.0119876	total: 1.95s	remaining: 27.7ms
# 986:	learn: 0.0119854	total: 1.95s	remaining: 25.7ms
# 987:	learn: 0.0119834	total: 1.96s	remaining: 23.8ms
# 988:	learn: 0.0119752	total: 1.96s	remaining: 21.8ms
# 989:	learn: 0.0119703	total: 1.96s	remaining: 19.8ms
# 990:	learn: 0.0119539	total: 1.96s	remaining: 17.8ms
# 991:	learn: 0.0119438	total: 1.96s	remaining: 15.8ms
# 992:	learn: 0.0119246	total: 1.96s	remaining: 13.8ms
# 993:	learn: 0.0119143	total: 1.97s	remaining: 11.9ms
# 994:	learn: 0.0119129	total: 1.97s	remaining: 9.89ms
# 995:	learn: 0.0118972	total: 1.97s	remaining: 7.91ms
# 996:	learn: 0.0118863	total: 1.97s	remaining: 5.93ms
# 997:	learn: 0.0118718	total: 1.97s	remaining: 3.95ms
# 998:	learn: 0.0118607	total: 1.98s	remaining: 1.98ms
# 999:	learn: 0.0118522	total: 1.98s	remaining: 0us

# %%
print(transformed_X_train)
# Out:
#       delta_h_mix  delta_s_mix  delta_d  delta_e  rnn_encoding
# 0            0.26         0.03     0.49     0.26          0.40
# 1            0.46         1.00     0.44     0.45          0.83
# 2            0.36         0.79     0.76     0.22          0.64
# 3            0.20         0.64     0.74     0.00          0.53
# 4            0.77         0.60     0.44     0.42          0.51
# ...           ...          ...      ...      ...           ...
# 1316         0.37         0.66     0.77     0.19          0.68
# 1317         0.19         0.49     0.81     0.39          0.51
# 1318         0.61         0.09     0.41     0.80          0.17
# 1319         0.05         0.73     0.95     0.11          0.85
# 1320         0.24         0.84     0.48     0.02          0.51
#
# [1321 rows x 5 columns]
